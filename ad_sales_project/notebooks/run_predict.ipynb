# %% [markdown]
# # Prediction System
# This notebook demonstrates the reusable prediction function for advertising sales.

# %%
import sys
sys.path.append('../src')
from predict import predict_sales

models_dir = '../models'
data_path = '../data/cleaned_advertising.csv'
# Example input
tv = 150
radio = 25
newspaper = 20
pred, model_name = predict_sales(tv, radio, newspaper, models_dir, data_path)
print(f'Predicted Sales: {pred:.2f} (using {model_name})')
