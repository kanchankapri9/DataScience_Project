# %% [markdown]
# # Train and Evaluate Models
# This notebook runs the model training pipeline, evaluates multiple models, and saves the best one.

# %%
import sys
sys.path.append('../src')
from train_models import run_training
run_training()
