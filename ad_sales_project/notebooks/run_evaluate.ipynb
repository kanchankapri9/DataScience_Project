# %% [markdown]
# # Model Evaluation
# This notebook evaluates the tuned model and generates evaluation metrics and plots.

# %%
import sys
sys.path.append('../src')
from evaluate import run_evaluation
run_evaluation()
