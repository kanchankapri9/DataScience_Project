# %% [markdown]
# # Run EDA Pipeline
# This notebook runs the EDA pipeline to generate and save charts, and write insights.

# %%
import sys
sys.path.append('../src')
from eda import run_eda
run_eda()
